# %%
Carrito = []

while True:

  print("Menu del Carrito")
  print("Agregar al Carrito")
  print("Eliminar Productos")
  print("Ver Carrito")
  print("Salir")

  opc = input("Elige una opcion:")

  if opc == "1":
    producto = input("Ingresa el nombre del producto:")
    Carrito.append(producto)
    print(producto,"agregado al carrito")

  elif opc == "2":
    producto = input("Ingresa el producto que quiere eliminar:")
    if producto in Carrito:
      Carrito.remove(producto)
      print(producto,"eliminado del carrito")
    else:
      print("El producto no esta en el carrito")

  elif opc == "3":
    if Carrito:
      print("Contenido del Carrito",Carrito)

    else:
      print("El carrito esta vacio")

  elif opc == "4":
    print("Saliendo del Progama")
    break
  else:
    print("Opcion invalida , intente de nuevo")
# Out:
# Menu del Carrito
# Agregar al Carrito
# Eliminar Productos
# Ver Carrito
# Salir
# Elige una opcion:1
# Ingresa el nombre del producto:a
# a agregado al carrito
# Menu del Carrito
# Agregar al Carrito
# Eliminar Productos
# Ver Carrito
# Salir
# Elige una opcion:1
# Ingresa el nombre del producto:e
# e agregado al carrito
# Menu del Carrito
# Agregar al Carrito
# Eliminar Productos
# Ver Carrito
# Salir
# Elige una opcion:3
# Contenido del Carrito ['a', 'e']
# Menu del Carrito
# Agregar al Carrito
# Eliminar Productos
# Ver Carrito
# Salir
# Elige una opcion:2
# Ingresa el producto que quiere eliminar:e
# e eliminado del carrito
# Menu del Carrito
# Agregar al Carrito
# Eliminar Productos
# Ver Carrito
# Salir
# Elige una opcion:3
# Contenido del Carrito ['a']
# Menu del Carrito
# Agregar al Carrito
# Eliminar Productos
# Ver Carrito
# Salir
# Elige una opcion:1
# Ingresa el nombre del producto:f
# f agregado al carrito
# Menu del Carrito
# Agregar al Carrito
# Eliminar Productos
# Ver Carrito
# Salir
# Elige una opcion:3
# Contenido del Carrito ['a', 'f']
# Menu del Carrito
# Agregar al Carrito
# Eliminar Productos
# Ver Carrito
# Salir
# Elige una opcion:5
# Opcion invalida , intente de nuevo
# Menu del Carrito
# Agregar al Carrito
# Eliminar Productos
# Ver Carrito
# Salir
# Elige una opcion:4
# Saliendo del Progama

# %%
roles_validos = ("admin","editor","visitante")
usuarios = []
while True:
  print("Registrate")
  nombre = input("ingresqa nombre del usuario (o salir para terminar el para terminar):")
  if nombre.lower()== "salir":
    break
  rol = input("ingresar el rol(admin, editor, visitante):")

  if rol in roles_validos:
    usuarios.append((nombre,rol))
    print("usuario",nombre,"con rol",rol,"registrado")
  else:
    print("rol invalido,intentar de nuevo")

print("lista de usuarios registrados:")
for usuario in usuarios:
  print(usuarios)
# Out:
# Registrate
# ingresqa nombre del usuario (o salir para terminar el para terminar):juan
# ingresar el rol(admin, editor, visitante):admin
# usuario juan con rol admin registrado
# Registrate
# ingresqa nombre del usuario (o salir para terminar el para terminar):carolina
# ingresar el rol(admin, editor, visitante):editor
# usuario carolina con rol editor registrado
# Registrate
# ingresqa nombre del usuario (o salir para terminar el para terminar):salir
# lista de usuarios registrados:
# [('juan', 'admin'), ('carolina', 'editor')]
# [('juan', 'admin'), ('carolina', 'editor')]

# %%
Agenda = {}

while True:
  print("Menu de Agenda")
  print("1. Agregar Contacto")
  print("2. Buscar Contacto")
  print("3. Mostrar todos los contactos")
  print("4. Salir")
  opc = input("Elige una opcion:")

  if opc == "1":
    nombre = input("Ingresa el nombre del contacto:")
    telefono = input("Ingresa el telefono del contacto:")
    Agenda.update({nombre : telefono})
    print("contacto",nombre,"agendado")

  elif opc == "2":
    nombre = input("Nombre a buscar:")
    telefono = Agenda.get(nombre)
    if telefono:
      print(nombre,telefono)
    else:
      print("contacto inexistente")

  elif opc == "3":
    if Agenda:
      print("Lista de contactos:")
      for nombre,telefono in Agenda.items():
        print(nombre,telefono)
    else:
      print("Agenda vacia")

  elif opc == "4":
    print("Saliendo del programa")
    break

  else:
    print("Opcion invalida, intente de nuevo")
# Out:
# Menu de Agenda
# 1. Agregar Contacto
# 2. Buscar Contacto
# 3. Mostrar todos los contactos
# 4. Salir
# Elige una opcion:1
# Ingresa el nombre del contacto:juan
# Ingresa el telefono del contacto:10
# contacto juan agendado
# Menu de Agenda
# 1. Agregar Contacto
# 2. Buscar Contacto
# 3. Mostrar todos los contactos
# 4. Salir
# Elige una opcion:1
# Ingresa el nombre del contacto:carolina
# Ingresa el telefono del contacto:20
# contacto carolina agendado
# Menu de Agenda
# 1. Agregar Contacto
# 2. Buscar Contacto
# 3. Mostrar todos los contactos
# 4. Salir
# Elige una opcion:1
# Ingresa el nombre del contacto:laura
# Ingresa el telefono del contacto:30
# contacto laura agendado
# Menu de Agenda
# 1. Agregar Contacto
# 2. Buscar Contacto
# 3. Mostrar todos los contactos
# 4. Salir
# Elige una opcion:3
# Lista de contactos:
# juan 10
# carolina 20
# laura 30
# Menu de Agenda
# 1. Agregar Contacto
# 2. Buscar Contacto
# 3. Mostrar todos los contactos
# 4. Salir
# Elige una opcion:2
# Nombre a buscar:carolina
# carolina 20
# Menu de Agenda
# 1. Agregar Contacto
# 2. Buscar Contacto
# 3. Mostrar todos los contactos
# 4. Salir
# Elige una opcion:4
# Saliendo del programa

# %%
votos = {"rojo": 0 ,"Azul": 0 ,"Verde": 0 ,"Amarillo": 0}

while True:
  print("Votacion de colores Favoritos")
  print("colores disponibles:", list(votos.keys()))
  print("Escribe salir para terminar resultados")

  color = input("vota por un color:").lower()

  if color == "salir":
    break

  elif color in votos:
    votos[color] += 1
    print("voto registrado por",color)
  else:
    print("opcion invalida, intente de nuevo")

print("resultados de la votacion:")
for color,cantidad in votos.items():
  print(color,votos,"votos")
# Out:
# Votacion de colores Favoritos
# colores disponibles: ['rojo', 'Azul', 'Verde', 'Amarillo']
# Escribe salir para terminar resultados
# vota por un color:azul
# opcion invalida, intente de nuevo
# Votacion de colores Favoritos
# colores disponibles: ['rojo', 'Azul', 'Verde', 'Amarillo']
# Escribe salir para terminar resultados
# vota por un color:azul
# opcion invalida, intente de nuevo
# Votacion de colores Favoritos
# colores disponibles: ['rojo', 'Azul', 'Verde', 'Amarillo']
# Escribe salir para terminar resultados
# vota por un color:rojo
# voto registrado por rojo
# Votacion de colores Favoritos
# colores disponibles: ['rojo', 'Azul', 'Verde', 'Amarillo']
# Escribe salir para terminar resultados
# vota por un color:verde
# opcion invalida, intente de nuevo
# Votacion de colores Favoritos
# colores disponibles: ['rojo', 'Azul', 'Verde', 'Amarillo']
# Escribe salir para terminar resultados
# vota por un color:salir
# resultados de la votacion:
# rojo {'rojo': 1, 'Azul': 0, 'Verde': 0, 'Amarillo': 0} votos
# Azul {'rojo': 1, 'Azul': 0, 'Verde': 0, 'Amarillo': 0} votos
# Verde {'rojo': 1, 'Azul': 0, 'Verde': 0, 'Amarillo': 0} votos
# Amarillo {'rojo': 1, 'Azul': 0, 'Verde': 0, 'Amarillo': 0} votos
